# %%
# %pip install mediapipe opencv-python

# %%
import cv2
import mediapipe as mp
import numpy as np
from PIL import Image
from pprint import pprint
import pyttsx3

tts = pyttsx3.init()
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
mp_drawing_styles = mp.solutions.drawing_styles

# %%
from pathlib import Path

img_path = Path(r"C:\Users\manoj\Downloads\handstand.png")
video_path = Path(r"C:\Users\manoj\Downloads\handstandgit.mp4")
long_video_path = Path(r"C:\Users\manoj\Downloads\handstandlong.mp4")
print(str(video_path))
# Out:
# C:\Users\manoj\Downloads\handstandgit.mp4

# %%
def get_angle(a: list[float], b: list[float], c: list[float]) -> float:
    a = np.array(a)  # First
    b = np.array(b)  # Mid
    c = np.array(c)  # End

    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(
        a[1] - b[1], a[0] - b[0]
    )
    angle = np.abs(radians * 180.0 / np.pi)

    if angle > 180.0:
        angle = 360 - angle

    return angle


def get_all_angles(modifiedlandmarks: dict[str, list[float]]) -> dict[str, float]:
    angles = {
        "LEFT_ELBOW": get_angle(
            modifiedlandmarks["LEFT_SHOULDER"],
            modifiedlandmarks["LEFT_ELBOW"],
            modifiedlandmarks["LEFT_WRIST"],
        ),
        "RIGHT_ELBOW": get_angle(
            modifiedlandmarks["RIGHT_SHOULDER"],
            modifiedlandmarks["RIGHT_ELBOW"],
            modifiedlandmarks["RIGHT_WRIST"],
        ),
        "LEFT_SHOULDER": get_angle(
            modifiedlandmarks["LEFT_HIP"],
            modifiedlandmarks["LEFT_SHOULDER"],
            modifiedlandmarks["LEFT_ELBOW"],
        ),
        "RIGHT_SHOULDER": get_angle(
            modifiedlandmarks["RIGHT_HIP"],
            modifiedlandmarks["RIGHT_SHOULDER"],
            modifiedlandmarks["RIGHT_ELBOW"],
        ),
        "LEFT_HIP": get_angle(
            modifiedlandmarks["LEFT_SHOULDER"],
            modifiedlandmarks["LEFT_HIP"],
            modifiedlandmarks["LEFT_KNEE"],
        ),
        "RIGHT_HIP": get_angle(
            modifiedlandmarks["RIGHT_SHOULDER"],
            modifiedlandmarks["RIGHT_HIP"],
            modifiedlandmarks["RIGHT_KNEE"],
        ),
        "LEFT_KNEE": get_angle(
            modifiedlandmarks["LEFT_HIP"],
            modifiedlandmarks["LEFT_KNEE"],
            modifiedlandmarks["LEFT_ANKLE"],
        ),
        "RIGHT_KNEE": get_angle(
            modifiedlandmarks["RIGHT_HIP"],
            modifiedlandmarks["RIGHT_KNEE"],
            modifiedlandmarks["RIGHT_ANKLE"],
        ),
    }
    return angles


def verify_angles(
    angles: dict[str, float], lower_angle: int = 150, upper_angle: int = 180
) -> tuple[bool, str | None]:
    for point in angles:
        if not (lower_angle <= angles[point] <= upper_angle):
            return False, point
    return True, None


def draw_landmarks(
    image, angles: dict[str, float], landmarks: dict[str, list[float]]
) -> None:
    for point in angles.keys():
        cv2.putText(
            image,
            f"{angles[point]:.2f}",
            tuple(
                np.multiply(landmarks[point], [image.shape[1], image.shape[0]]).astype(
                    int
                )
            ),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.5,
            (255, 255, 255),
            2,
            cv2.LINE_AA,
        ),


def write_to_file(file_name: str = "file.txt", content: str = "") -> None:
    with open(file_name, "w") as file:
        file.write(content)


def read_from_file(file_name: str = "file.txt") -> str:
    try:
        with open(file_name, "r") as file:
            return file.read()
    except FileNotFoundError:
        return ""


def get_important_landmarks(landmarks) -> dict[str, list[float]]:
    important_points = [
        "LEFT_WRIST",
        "RIGHT_WRIST",
        "LEFT_ELBOW",
        "RIGHT_ELBOW",
        "LEFT_SHOULDER",
        "RIGHT_SHOULDER",
        "LEFT_HIP",
        "RIGHT_HIP",
        "LEFT_KNEE",
        "RIGHT_KNEE",
        "LEFT_ANKLE",
        "RIGHT_ANKLE",
    ]
    return {
        point: [
            landmarks[mp_pose.PoseLandmark[point].value].x,
            landmarks[mp_pose.PoseLandmark[point].value].y,
        ]
        for point in important_points
    }

# %%
# VIDEO FEED
cap = cv2.VideoCapture(str(video_path))
# cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    cv2.imshow("Mediapipe Feed", cv2.flip(frame, 1))

    if cv2.waitKey(10) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()

# %%
IMAGE_FILES = [str(img_path)]
BG_COLOR = (192, 192, 192)  # gray
with mp_pose.Pose(
    static_image_mode=True,
    model_complexity=2,
    enable_segmentation=False,
    min_detection_confidence=0.5,
) as pose:
    for idx, file in enumerate(IMAGE_FILES):
        frame = cv2.imread(file)

        # Recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        # Make detection
        results = pose.process(image)

        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark
        except:
            pass

        modified_landmarks = get_important_landmarks(landmarks)
        angles = get_all_angles(modified_landmarks)
        draw_landmarks(image, angles, modified_landmarks)

        mp_drawing.draw_landmarks(
            image,
            results.pose_landmarks,
            mp_pose.POSE_CONNECTIONS,
            landmark_drawing_spec=mp_drawing_styles.get_default_pose_landmarks_style(),
        )

        Image.fromarray(image).show()

# %%
cap = cv2.VideoCapture(str(long_video_path))
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
fps = cap.get(cv2.CAP_PROP_FPS)
print(f"Total frames: {total_frames}, FPS: {fps}")
# Out:
# Total frames: 1907, FPS: 30.0

# %%
import threading
from time import sleep


def speak():
    tts = pyttsx3.init()
    tts.setProperty("rate", 150)  # Set speech rate
    while True:
        content = read_from_file(file_name="file.txt")
        if content:
            if tts._inLoop:
                tts.endLoop()
            tts.say(content)
            tts.runAndWait()
            write_to_file(file_name="file.txt", content="")
        sleep(2)


thread = threading.Thread(target=speak, daemon=True)

# %%
thread.join(1)

# %%
thread.is_alive()
# Out:
# False

# %%
cap = cv2.VideoCapture(str(long_video_path))
## Setup mediapipe instance
with mp_pose.Pose(
    min_detection_confidence=0.6,
    min_tracking_confidence=0.6,
) as pose:
    thread.start()
    while cap.isOpened():
        success, frame = cap.read()
        if not success:
            break

        # Flip the image horizontally for a later selfie-view display
        image = cv2.flip(frame, 1)

        # Recolor image to RGB
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        # Make detection
        results = pose.process(image)

        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark
        except:
            pass

        # Draw landmarks and angles
        modified_landmarks = get_important_landmarks(landmarks)
        angles = get_all_angles(modified_landmarks)
        draw_landmarks(image, angles, modified_landmarks)

        # Verify angles
        verify, point = verify_angles(angles, lower_angle=150, upper_angle=180)
        if not verify:
            write_to_file(file_name="file.txt", content=point.replace("_", " "))
        print(verify, point, angles[point] if not verify else None)

        # Render detections
        mp_drawing.draw_landmarks(
            image,
            results.pose_landmarks,
            mp_pose.POSE_CONNECTIONS,
            landmark_drawing_spec=mp_drawing_styles.get_default_pose_landmarks_style(),
        )

        cv2.imshow("Handstand", image)

        if cv2.waitKey(10) & 0xFF == ord("q"):
            write_to_file(file_name="file.txt", content="")
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# False LEFT_HIP 100.02057704095775
# False LEFT_HIP 99.01341164585155
# False LEFT_HIP 98.04441568577343
# False LEFT_HIP 96.31733966933496
# False LEFT_HIP 95.97206464685793
# False LEFT_HIP 94.36872540147054
# False LEFT_SHOULDER 148.95400959893252
# False LEFT_SHOULDER 147.6458463271407
# False LEFT_SHOULDER 144.94340072093863
# False LEFT_SHOULDER 143.29458165453772
# False LEFT_SHOULDER 138.65636032905346
# False LEFT_SHOULDER 133.60746238481687
# False LEFT_SHOULDER 129.45145197738944
# False LEFT_SHOULDER 125.73700890324335
# False LEFT_SHOULDER 123.77768791102787
# False LEFT_SHOULDER 119.56940363197835
# False LEFT_SHOULDER 117.5957676972367
# False LEFT_SHOULDER 111.8536254017499
# False LEFT_ELBOW 148.7149366924111
# False LEFT_ELBOW 147.99385325414767
# False LEFT_ELBOW 148.98818525118898
# False LEFT_SHOULDER 99.95319784937799
# False LEFT_SHOULDER 103.45828259874716
# False LEFT_SHOULDER 105.70421621795424
# False LEFT_SHOULDER 110.12924232176522
# False LEFT_SHOULDER 115.38271262205299
# False LEFT_SHOULDER 118.70505001230006
# False LEFT_SHOULDER 126.04986138876494
# False LEFT_SHOULDER 129.31667462038385
# False LEFT_SHOULDER 133.8389992526288
# False LEFT_SHOULDER 136.40207871330364
# False LEFT_SHOULDER 136.4796435781391
# False LEFT_SHOULDER 135.93705166912076
# False LEFT_SHOULDER 137.207094367018
# False LEFT_SHOULDER 138.9608349965863
# False LEFT_SHOULDER 139.25725132558696
# False LEFT_SHOULDER 139.9511584495106
# False LEFT_SHOULDER 141.12989557042746
# False LEFT_SHOULDER 142.68099312676966
# False LEFT_SHOULDER 143.8297347021382
# False LEFT_SHOULDER 143.83589088984516
# False LEFT_SHOULDER 144.03855003618636
# False LEFT_SHOULDER 143.8372664832729
# False LEFT_SHOULDER 143.10129342432163
# False LEFT_SHOULDER 142.51861465654787
# False LEFT_SHOULDER 140.73038419535354
# False LEFT_SHOULDER 139.54061643512537
# False LEFT_SHOULDER 139.98763535819216
# False LEFT_SHOULDER 141.14402690066467
# False LEFT_SHOULDER 143.0331408994189
# False LEFT_SHOULDER 145.63275253814612
# False LEFT_SHOULDER 146.77700487928368
# False LEFT_SHOULDER 146.29266260655845
# False LEFT_SHOULDER 145.77858456470858
# False LEFT_SHOULDER 145.56543035901862
# False LEFT_SHOULDER 145.27908106272923
# False LEFT_SHOULDER 144.82012839555426
# False LEFT_SHOULDER 144.14536601306617
# False LEFT_SHOULDER 143.9832231187921
# False LEFT_SHOULDER 143.98287179857093
# False LEFT_SHOULDER 143.4347033439328
# False LEFT_SHOULDER 143.08872371124806
# False LEFT_ELBOW 149.35774192198903
# False LEFT_ELBOW 147.67828676816
# False LEFT_ELBOW 146.89477732831327
# False LEFT_ELBOW 146.30381411801488
# False LEFT_ELBOW 146.92658798807997
# False LEFT_ELBOW 147.32410189554167
# False LEFT_ELBOW 147.90027396988617
# False LEFT_ELBOW 148.16510502001455
# False LEFT_ELBOW 148.0264519451881
# False LEFT_ELBOW 148.6583380358692
# False LEFT_ELBOW 149.79463858702186
# False LEFT_SHOULDER 149.69581129052642
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# False LEFT_SHOULDER 149.77362343132364
# False LEFT_SHOULDER 149.5214673220583
# False LEFT_SHOULDER 149.3717267725193
# False LEFT_SHOULDER 148.95980262611062
# False LEFT_SHOULDER 148.5612070153104
# False LEFT_SHOULDER 148.37571321193963
# False LEFT_SHOULDER 148.35800268199273
# False LEFT_SHOULDER 148.5552540547479
# False LEFT_SHOULDER 148.96537814077143
# False LEFT_SHOULDER 148.78388820527874
# False LEFT_SHOULDER 148.86340999532115
# False LEFT_SHOULDER 148.94192308773015
# False LEFT_SHOULDER 149.01587981508396
# False LEFT_SHOULDER 149.08118998372444
# False LEFT_SHOULDER 149.03533667937998
# False LEFT_SHOULDER 148.76394843914957
# False LEFT_SHOULDER 148.36232145439516
# False LEFT_SHOULDER 148.17021808525445
# False LEFT_SHOULDER 148.11712755457629
# False LEFT_SHOULDER 148.09699810323076
# False LEFT_SHOULDER 148.5434329730644
# False LEFT_SHOULDER 148.71543019120386
# False LEFT_SHOULDER 148.81092080679545
# False LEFT_SHOULDER 148.87317187411193
# False LEFT_SHOULDER 149.1291230159758
# False LEFT_SHOULDER 149.4841015213808
# False LEFT_SHOULDER 149.52229983490213
# False LEFT_SHOULDER 149.5054947768877
# False LEFT_SHOULDER 149.4820359328426
# False LEFT_SHOULDER 149.5395697018157
# False LEFT_SHOULDER 149.56482800519962
# False LEFT_SHOULDER 149.62540833117478
# False LEFT_SHOULDER 149.62450180117563
# False LEFT_SHOULDER 149.59354124450863
# False LEFT_SHOULDER 149.58278087057263
# False LEFT_SHOULDER 149.58128690036915
# False LEFT_SHOULDER 149.5671696317558
# False LEFT_SHOULDER 149.51753718079908
# False LEFT_SHOULDER 149.31111979869783
# False LEFT_SHOULDER 149.0697247875567
# False LEFT_SHOULDER 148.85564669939234
# False LEFT_SHOULDER 148.80000109731202
# False LEFT_SHOULDER 148.8996771551916
# False LEFT_SHOULDER 149.0416607989153
# False LEFT_SHOULDER 149.2105092925184
# False LEFT_SHOULDER 149.3307431915573
# False LEFT_SHOULDER 149.4277261993058
# False LEFT_SHOULDER 149.48311086695904
# False LEFT_SHOULDER 149.52361500545683
# False LEFT_SHOULDER 149.60002792853084
# False LEFT_SHOULDER 149.71882626424662
# False LEFT_SHOULDER 149.86842482733596
# False LEFT_SHOULDER 149.97006800842485
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# False LEFT_SHOULDER 149.92897961943044
# False LEFT_SHOULDER 149.9419850438621
# False LEFT_SHOULDER 149.99889261947206
# True None None
# True None None
# True None None
# True None None
# Exception in thread Thread-4 (speak):
# Traceback (most recent call last):
#   File "c:\Users\manoj\anaconda3\envs\ds\Lib\threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "c:\Users\manoj\anaconda3\envs\ds\Lib\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "c:\Users\manoj\anaconda3\envs\ds\Lib\threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\manoj\AppData\Local\Temp\ipykernel_157748\3474359796.py", line 14, in speak
#   File "c:\Users\manoj\anaconda3\envs\ds\Lib\site-packages\pyttsx3\engine.py", line 180, in runAndWait
#     raise RuntimeError('run loop already started')
# RuntimeError: run loop already started
# True None None
# True None None
# False LEFT_SHOULDER 149.60566369262597
# False LEFT_SHOULDER 149.24685817510004
# False LEFT_SHOULDER 148.44486117494287
# False LEFT_SHOULDER 147.48744540206303
# False LEFT_SHOULDER 147.09859253333488
# False LEFT_SHOULDER 146.89751147332535
# False LEFT_SHOULDER 147.02909439348647
# False LEFT_SHOULDER 147.0641236507498
# False LEFT_SHOULDER 147.0520854450337
# False LEFT_SHOULDER 147.0336756981324
# False LEFT_SHOULDER 147.03148356875698
# False LEFT_SHOULDER 146.89691773048276
# False LEFT_SHOULDER 146.86215453078353
# False LEFT_SHOULDER 146.62509950856685
# False LEFT_SHOULDER 146.27704949735943
# False LEFT_SHOULDER 146.15167602859995
# False LEFT_SHOULDER 146.05700626000367
# False LEFT_SHOULDER 146.08962191288683
# False LEFT_SHOULDER 146.24974780796873
# False LEFT_SHOULDER 146.31677100554225
# False LEFT_SHOULDER 146.43063582663558
# False LEFT_SHOULDER 146.59399894800967
# False LEFT_SHOULDER 146.76203586989288
# False LEFT_SHOULDER 147.29664274377592
# False LEFT_SHOULDER 147.7029791905414
# False LEFT_SHOULDER 147.9399320239662
# False LEFT_SHOULDER 148.02853953889186
# False LEFT_SHOULDER 148.22372528674867
# False LEFT_SHOULDER 148.30234516260015
# False LEFT_SHOULDER 149.04160289632546
# False LEFT_SHOULDER 149.8060807850781
# False LEFT_HIP 149.59761003575525
# False LEFT_HIP 149.6743913246617
# False LEFT_HIP 149.4967972356047
# False LEFT_HIP 149.269955619686
# False LEFT_HIP 149.0225470937049
# False LEFT_HIP 148.75999958656521
# False LEFT_HIP 148.64973509867994
# False LEFT_HIP 148.60792351597445
# False LEFT_HIP 148.61295447920207
# False LEFT_HIP 148.65478511109012
# False LEFT_HIP 148.69479628472476
# False LEFT_HIP 148.65982306789158
# False LEFT_HIP 148.6545408139961
# False LEFT_HIP 148.68103348172656
# False LEFT_HIP 148.72684859791735
# False LEFT_HIP 148.76349265779524
# False LEFT_HIP 148.87052652331502
# False LEFT_HIP 148.98862531205532
# False LEFT_HIP 149.06425921746828
# False LEFT_HIP 149.15957481889407
# False LEFT_HIP 149.1987800090867
# False LEFT_HIP 149.24129302178562
# False LEFT_HIP 149.220560670583
# False LEFT_HIP 149.16254771586452
# False LEFT_HIP 149.08258267254632
# False LEFT_HIP 148.93987985075626
# False LEFT_HIP 148.76990583301992
# False LEFT_HIP 148.62722896644598
# False LEFT_HIP 148.562439800895
# False LEFT_SHOULDER 149.956836106301
# False LEFT_SHOULDER 149.6536754775762
# False LEFT_SHOULDER 149.46838288946134
# False LEFT_SHOULDER 149.3768198820138
# False LEFT_SHOULDER 149.29451184954965
# False LEFT_SHOULDER 149.28221501420276
# False LEFT_SHOULDER 149.26665868409867
# False LEFT_SHOULDER 149.2387549005963
# False LEFT_SHOULDER 149.22752359478295
# False LEFT_SHOULDER 149.25626926581458
# False LEFT_SHOULDER 149.25415166422073
# False LEFT_SHOULDER 149.40158419796867
# False LEFT_SHOULDER 149.56773330270948
# False LEFT_SHOULDER 149.6872043102384
# False LEFT_SHOULDER 149.81173200223685
# False LEFT_SHOULDER 149.90291330151774
# False LEFT_SHOULDER 149.98339167891314
# False LEFT_SHOULDER 149.99593278241426
# False RIGHT_HIP 147.215592544995
# False RIGHT_HIP 147.519593284329
# False RIGHT_HIP 147.86655738375003
# False RIGHT_HIP 147.8846434018066
# False RIGHT_HIP 147.90226645899844
# False RIGHT_HIP 147.9336179651105
# False RIGHT_HIP 147.96076105204685
# False RIGHT_HIP 147.96152314808754
# False RIGHT_HIP 147.96338473181117
# False RIGHT_HIP 147.93077558454513
# False RIGHT_HIP 147.59972345193037
# False RIGHT_HIP 147.36209366879868
# False RIGHT_HIP 146.95107073300332
# False RIGHT_HIP 146.66220548173223
# False RIGHT_HIP 146.23268341568232
# False LEFT_SHOULDER 149.99526664201764
# False LEFT_SHOULDER 149.93105358697719
# False RIGHT_HIP 145.75773215579406
# False RIGHT_HIP 145.86976100867116
# False RIGHT_HIP 146.01152791750104
# False RIGHT_HIP 146.1663373893478
# False RIGHT_HIP 146.22974049774882
# False RIGHT_HIP 146.31757691089473
# False RIGHT_HIP 146.19639513750153
# False RIGHT_HIP 146.11058163171975
# False RIGHT_HIP 145.98897159576447
# False RIGHT_HIP 146.08303227563263
# False RIGHT_HIP 146.14795990223502
# False RIGHT_HIP 146.26402657353887
# False RIGHT_HIP 146.35231031702614
# False RIGHT_HIP 146.51327041628087
# False RIGHT_HIP 146.64874647937762
# False RIGHT_HIP 147.02393892627973
# False RIGHT_HIP 147.43886528389754
# False RIGHT_HIP 148.01411323732748
# False RIGHT_HIP 148.82742049413872
# False RIGHT_HIP 149.66457592042815
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# True None None
# False RIGHT_HIP 149.67291059575726
# False RIGHT_HIP 148.9250733903257
# False RIGHT_HIP 148.55578332623315
# False RIGHT_HIP 148.37446692088923
# False RIGHT_HIP 148.26544410059495
# False RIGHT_HIP 148.3021416728106
# False RIGHT_HIP 148.3595186906215
# False RIGHT_HIP 148.35593544361933
# False RIGHT_HIP 148.3497525900449
# False RIGHT_HIP 148.37338858628195
# False RIGHT_HIP 148.42057998318032
# False RIGHT_HIP 148.67236021478274
# False RIGHT_HIP 148.8683305593333
# False RIGHT_HIP 149.07283114735884
# False RIGHT_HIP 149.2403324565557
# False RIGHT_HIP 149.3490604906455
# False RIGHT_HIP 149.44080602962444
# False RIGHT_HIP 149.35382832522478
# False RIGHT_HIP 149.07849964758068
# False RIGHT_HIP 148.96815725624236
# False RIGHT_HIP 148.04047728144403
# False LEFT_SHOULDER 149.89587084554162
# False LEFT_SHOULDER 149.17423154089158
# False LEFT_SHOULDER 148.90557021629536
# False LEFT_SHOULDER 148.59446421923934
# False LEFT_SHOULDER 148.44121315639674
# False LEFT_SHOULDER 148.29767548151617
# False LEFT_SHOULDER 148.1926382287119
# False LEFT_SHOULDER 148.0234285592028
# False LEFT_SHOULDER 147.88389421397332
# False LEFT_SHOULDER 147.75514814719256
# False LEFT_SHOULDER 147.59881396298456
# False LEFT_SHOULDER 147.3397132136538
# False LEFT_SHOULDER 147.17118057902852
# False LEFT_SHOULDER 146.9707376070994
# False LEFT_SHOULDER 146.89013739034203
# False LEFT_SHOULDER 146.58915841140242
# False LEFT_SHOULDER 146.47636538087448
# False LEFT_SHOULDER 146.24874408770253
# False LEFT_SHOULDER 146.06587221793237
# False LEFT_SHOULDER 146.02457561599223
# False LEFT_SHOULDER 146.03233740236357
# False LEFT_SHOULDER 146.0990513240424
# False LEFT_SHOULDER 146.21633761574324
# False LEFT_SHOULDER 146.29607109826446
# False LEFT_SHOULDER 146.45331125937372
# False LEFT_SHOULDER 146.62618739768504
# False LEFT_SHOULDER 146.51554820232477
# False LEFT_SHOULDER 146.59461258964893
# False LEFT_SHOULDER 146.58462306506541
# False LEFT_SHOULDER 146.5981460802379
# False LEFT_SHOULDER 146.57324934935465
# False LEFT_SHOULDER 146.504001782671
# False LEFT_SHOULDER 146.40694287861155
# False LEFT_SHOULDER 146.22285394936756
# False LEFT_SHOULDER 146.0198248725832
# False LEFT_SHOULDER 145.84713533855845
# False LEFT_SHOULDER 145.6630612188993
# False LEFT_SHOULDER 145.55087933802852
# False LEFT_SHOULDER 145.46227889003956
# False LEFT_SHOULDER 145.33005115760358
# False LEFT_SHOULDER 145.42862928977783
# False LEFT_SHOULDER 145.76781701414527
# False LEFT_SHOULDER 146.25545765509796
# False LEFT_SHOULDER 147.04880795291817
# False LEFT_SHOULDER 147.66692451009672
# False LEFT_SHOULDER 148.6465561797919
# False LEFT_SHOULDER 148.9603475625027
# False LEFT_SHOULDER 149.38408287243004
# False LEFT_SHOULDER 149.15486066304294
# False LEFT_SHOULDER 149.13084580589708
# False LEFT_SHOULDER 149.15785906425253
# False LEFT_SHOULDER 149.13835347998113
# False LEFT_SHOULDER 149.11529763998993
# False LEFT_SHOULDER 149.12906374351644
# False LEFT_SHOULDER 149.1629923319363
# False LEFT_SHOULDER 149.16918176373
# False LEFT_SHOULDER 149.13206746305485
# False LEFT_SHOULDER 149.10705334717588
# False LEFT_SHOULDER 149.152830379006
# False LEFT_SHOULDER 149.20009034717492
# False LEFT_SHOULDER 149.2679631958044
# False LEFT_SHOULDER 149.1666679236518
# False LEFT_SHOULDER 148.74804544251754
# False LEFT_SHOULDER 148.54538905752256
# False LEFT_SHOULDER 148.5086989348411
# False LEFT_SHOULDER 148.66015918527603
# False LEFT_SHOULDER 148.73617485442793
# False LEFT_SHOULDER 148.63377832467427
# False LEFT_SHOULDER 148.38955054469383
# False LEFT_SHOULDER 148.2060787092769
# False LEFT_SHOULDER 147.98818477801024
# False LEFT_SHOULDER 148.0223930918187
# False LEFT_SHOULDER 148.07383718644036
# False LEFT_SHOULDER 148.15440829673653
# False LEFT_SHOULDER 148.39668396148463
# False LEFT_SHOULDER 148.54349439934236
# False LEFT_SHOULDER 148.7199354125343
# False LEFT_SHOULDER 148.84338760940318
# False LEFT_SHOULDER 149.0122501660392
# False LEFT_SHOULDER 149.13408832654926
# False LEFT_SHOULDER 149.19810467996385
# False LEFT_SHOULDER 149.29440852856047
# False LEFT_SHOULDER 149.37169499813058
# False LEFT_SHOULDER 149.44750900607377
# False LEFT_SHOULDER 149.59156128352848
# False LEFT_SHOULDER 149.65834553825968
# False LEFT_SHOULDER 149.7498455220764
# False LEFT_SHOULDER 149.93842319938565
# False LEFT_HIP 149.1704361769649
# False LEFT_HIP 149.22357655428388
# False LEFT_HIP 149.30401990687412
# False LEFT_HIP 149.3330022262917
# False LEFT_HIP 149.32908207214803
# False LEFT_HIP 149.33401935002433
# False LEFT_HIP 149.3634516962151
# False LEFT_HIP 149.32951881544815
# False LEFT_HIP 149.2865436936586
# False LEFT_HIP 149.22536384240377
# False LEFT_HIP 149.15190930388263
# False LEFT_HIP 149.10419390506027
# False LEFT_HIP 149.10057979002866
# False LEFT_HIP 149.0559919287821
# False LEFT_HIP 149.029627137374
# False LEFT_HIP 148.87296830578003
# False LEFT_HIP 148.562881846892
# False LEFT_HIP 148.36142616576598
# False LEFT_HIP 148.05501150122393
# False LEFT_HIP 148.03947076340555
# False LEFT_HIP 148.21702106554955
# False LEFT_HIP 148.281210598849
# False LEFT_HIP 148.34792806950264
# False LEFT_HIP 148.38700515953977
# False LEFT_HIP 148.43136372322357
# False LEFT_HIP 148.45581106583063
# False LEFT_HIP 148.54000686150084
# False LEFT_HIP 148.71572422303026
# False LEFT_HIP 148.89546878642844
# False LEFT_HIP 149.0188265086081
# False LEFT_HIP 149.0986524989182
# False LEFT_HIP 149.11520656993676
# False LEFT_HIP 149.1116876553231
# False LEFT_HIP 149.08065945154948
# False LEFT_HIP 148.9876860599452
# False LEFT_HIP 148.9298114306832
# False LEFT_HIP 148.78816317574353
# False LEFT_HIP 148.69872967558055
# False LEFT_HIP 148.62928633828926
# False LEFT_HIP 148.6278838400206
# False LEFT_HIP 148.6525030386167
# False LEFT_HIP 149.1142423950246
# False LEFT_SHOULDER 149.88627494757793
# False LEFT_SHOULDER 149.68867032477402
# False LEFT_SHOULDER 149.35388490824786
# False LEFT_SHOULDER 149.20905107746833
# False LEFT_SHOULDER 149.17118339983762
# False LEFT_SHOULDER 149.1568116124193
# False LEFT_SHOULDER 148.98901548718828
# False LEFT_SHOULDER 148.97554198948353
# False LEFT_SHOULDER 149.00867703129475
# False LEFT_SHOULDER 149.13515804875752
# False LEFT_SHOULDER 149.13461421323154
# False LEFT_SHOULDER 149.29137396982037
# False LEFT_SHOULDER 149.64759715210488
# False LEFT_SHOULDER 149.88248402529715
# False LEFT_SHOULDER 149.9653618346406
# False LEFT_HIP 149.84489910462884
# False RIGHT_HIP 146.51686007798077
# False RIGHT_HIP 146.52916247120635
# False RIGHT_HIP 146.5971883176305
# False RIGHT_HIP 146.58395671949373
# False RIGHT_HIP 146.5677467215758
# False RIGHT_HIP 146.62401930155065
# False RIGHT_HIP 146.6600989179234
# False RIGHT_HIP 146.65772329625224
# False RIGHT_HIP 146.5929454599236
# False RIGHT_HIP 146.31433203593792
# False RIGHT_HIP 146.2090697466674
# False RIGHT_HIP 146.07583736025057
# False LEFT_SHOULDER 149.50299467047742
# False LEFT_SHOULDER 148.78283401190978
# False LEFT_SHOULDER 148.28197360198993
# False LEFT_SHOULDER 148.32632037688867
# False LEFT_SHOULDER 148.42399867256663
# False LEFT_SHOULDER 148.60091716630225
# False LEFT_SHOULDER 148.83829176087468
# False LEFT_SHOULDER 149.07657110580254
# False LEFT_SHOULDER 149.20789936949592
# False LEFT_SHOULDER 149.3024691635196
# False LEFT_SHOULDER 149.2676681505347
# False LEFT_SHOULDER 149.3215169226461
# False LEFT_SHOULDER 149.36418171238734
# False LEFT_SHOULDER 149.42693429923045
# False LEFT_SHOULDER 149.47683771364385
# False LEFT_SHOULDER 149.55519789137637
# False LEFT_SHOULDER 149.63359082776424
# False LEFT_SHOULDER 149.7604331217183
# False LEFT_SHOULDER 149.79512420748208
# False LEFT_SHOULDER 149.70069769550096
# False LEFT_SHOULDER 149.56657270060816
# False LEFT_SHOULDER 149.35836111340848
# False LEFT_SHOULDER 149.05376116610412
# False LEFT_SHOULDER 149.01270648220586
# False LEFT_SHOULDER 149.05987428366674
# False LEFT_SHOULDER 149.0854106563887
# False LEFT_SHOULDER 149.11174365282707
# False LEFT_SHOULDER 149.19637209779705
# False LEFT_SHOULDER 149.22858229552136
# False LEFT_SHOULDER 149.3033687646784
# False LEFT_SHOULDER 149.39330044356817
# False LEFT_SHOULDER 149.47953825829103
# False LEFT_SHOULDER 149.56141969518126
# False LEFT_SHOULDER 149.60559911239147
# False LEFT_SHOULDER 149.59249828062102
# False LEFT_SHOULDER 149.6073816717912
# False LEFT_SHOULDER 149.6083710832661
# False LEFT_SHOULDER 149.58855514958262
# False LEFT_SHOULDER 149.56686101608037
# False LEFT_SHOULDER 149.5908886559198
# False LEFT_SHOULDER 149.69325377826243
# False LEFT_SHOULDER 149.8270880006455
# False LEFT_HIP 149.3085541201748
# False LEFT_HIP 149.3472078261889
# False LEFT_HIP 149.35752301356248
# False LEFT_HIP 149.39502978556013
# False LEFT_SHOULDER 149.82043509856726
# False LEFT_SHOULDER 149.70097301780328
# False LEFT_SHOULDER 149.54100822842727
# False LEFT_SHOULDER 149.40948892644258
# False LEFT_SHOULDER 149.33824989313953
# False LEFT_SHOULDER 149.36079807466936
# False LEFT_SHOULDER 149.4896350119131
# False LEFT_SHOULDER 149.62699191813286
# False RIGHT_HIP 147.6729254364793
# False RIGHT_HIP 147.81468998298297
# False RIGHT_HIP 148.023562628818
# False RIGHT_HIP 148.12459378871318
# False RIGHT_HIP 148.31034088895476
# False RIGHT_HIP 148.3208372928822
# False RIGHT_HIP 148.29702063784856
# False RIGHT_HIP 148.3748162352923
# False RIGHT_HIP 148.45486274748274
# False RIGHT_HIP 148.5793615876457
# False RIGHT_HIP 148.83750871307322
# False RIGHT_HIP 149.09075336213192
# False RIGHT_HIP 149.2065673083762
# False RIGHT_HIP 149.12784564399146
# False RIGHT_HIP 149.46468771595
# False RIGHT_HIP 149.60735548140676
# False RIGHT_HIP 149.44807593639527
# False RIGHT_HIP 148.9944996088818
# False RIGHT_HIP 148.48467708429797
# False RIGHT_HIP 148.23356697072063
# False RIGHT_HIP 148.1518183460799
# False RIGHT_HIP 148.10781152639237
# False RIGHT_HIP 148.0674344515662
# False RIGHT_HIP 147.99960661025082
# False RIGHT_HIP 147.88108001436845
# False RIGHT_HIP 147.6901072706249
# False RIGHT_HIP 147.5610659768733
# False LEFT_SHOULDER 149.9992208324104
# False LEFT_SHOULDER 149.90063331553745
# False LEFT_SHOULDER 149.8011968505558
# False LEFT_SHOULDER 149.6599091927108
# False LEFT_SHOULDER 149.55259853565482
# False LEFT_SHOULDER 149.4787508218179
# False LEFT_SHOULDER 149.4765852683415
# False LEFT_SHOULDER 149.5403447200988
# False LEFT_SHOULDER 149.57024363216496
# False LEFT_SHOULDER 149.54759595975284
# False LEFT_SHOULDER 149.53625095644358
# False LEFT_SHOULDER 149.52895549879497
# False LEFT_SHOULDER 149.52389752988725
# False LEFT_SHOULDER 149.46777742686993
# False LEFT_SHOULDER 149.4363524479431
# False LEFT_SHOULDER 149.4783406315316
# False LEFT_SHOULDER 149.57024005855814
# False LEFT_SHOULDER 149.711264364132
# False RIGHT_HIP 145.62943870493106
# False RIGHT_HIP 145.53363999188193
# False RIGHT_HIP 146.05591050374812
# False RIGHT_HIP 146.48576206624264
# False RIGHT_HIP 146.8648875375636
# False RIGHT_HIP 147.2558812370458

# %%
mp_drawing.DrawingSpec??
# Out:
# Init signature:
# mp_drawing.DrawingSpec(
#     color: Tuple[int, int, int] = (224, 224, 224),
#     thickness: int = 2,
#     circle_radius: int = 2,
# ) -> None
# Docstring:      DrawingSpec(color: Tuple[int, int, int] = (224, 224, 224), thickness: int = 2, circle_radius: int = 2)
# Source:
# @dataclasses.dataclass
# class DrawingSpec:
#   # Color for drawing the annotation. Default to the white color.
#   color: Tuple[int, int, int] = WHITE_COLOR
#   # Thickness for drawing the annotation. Default to 2 pixels.
#   thickness: int = 2
#   # Circle radius. Default to 2 pixels.
#   circle_radius: int = 2
# File:           c:\users\manoj\anaconda3\envs\ds\lib\site-packages\mediapipe\python\solutions\drawing_utils.py
# Type:           type
# Subclasses:

# %%
important_landmarks = get_important_landmarks(landmarks)
pprint(important_landmarks)
# Out:
# {'LEFT_ANKLE': [0.46831968426704407, 0.1444380283355713],
#  'LEFT_ELBOW': [0.4429980516433716, 0.8268292546272278],
#  'LEFT_HIP': [0.4685867130756378, 0.4892749488353729],
#  'LEFT_KNEE': [0.4723130464553833, 0.31670740246772766],
#  'LEFT_SHOULDER': [0.4757247567176819, 0.7233765125274658],
#  'LEFT_WRIST': [0.4534723460674286, 0.9279065132141113],
#  'RIGHT_ANKLE': [0.4735932946205139, 0.13535618782043457],
#  'RIGHT_ELBOW': [0.4471559226512909, 0.8343253135681152],
#  'RIGHT_HIP': [0.472617506980896, 0.4935796558856964],
#  'RIGHT_KNEE': [0.474957138299942, 0.3151125907897949],
#  'RIGHT_SHOULDER': [0.4791662096977234, 0.7252435088157654],
#  'RIGHT_WRIST': [0.45731738209724426, 0.9484072923660278]}

# %%
angles = get_all_angles(landmarks=landmarks)
pprint(angles)
# Out:
# {'LEFT_ELBOW': 156.5292687461507,
#  'LEFT_HIP': 177.01649968909143,
#  'LEFT_KNEE': 177.43504620433345,
#  'LEFT_SHOULDER': 160.69904226792767,
#  'RIGHT_ELBOW': 158.5555700654588,
#  'RIGHT_HIP': 177.6297053974541,
#  'RIGHT_KNEE': 178.81421355048414,
#  'RIGHT_SHOULDER': 162.0263487644425}

# %%
verify_angles(angles)
# Out:
# True
